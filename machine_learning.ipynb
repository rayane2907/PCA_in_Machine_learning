# %% [markdown]
# <a href="https://colab.research.google.com/github/rayane2907/Machine_learning/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt
import numpy as np


x = numpy.random.normal(5.0, 1.0, 100000)

from numpy import random
x_data = np.random.randn(15)
y_data = np.random.randn(15)
plt.hist(x, 100)
plt.show()

from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x1, y1)

def myfunc(x1):
  return slope * x1 + intercept

mymodel = list(map(myfunc, x1))

plt.figure(1)
plt.scatter(x1, y1)
plt.plot(x1, mymodel, "red")

mymodel = numpy.poly1d(numpy.polyfit(x1, y1, 4))

myline = numpy.linspace(0, 1, 100)

plt.figure(2)
plt.scatter(x1, y1)
plt.plot(myline, mymodel(myline),"green")
plt.show()

# %%
def generate_scatter_plot(x_data, y_data, x_label, y_label, title):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.scatter(x_data, y_data)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    plt.show()

def generate_hexbin_plot(x_data, y_data, x_label, y_label, title):
    fig, ax = plt.subplots(figsize=(10, 8))
    hb = ax.hexbin(x_data, y_data, gridsize=25, cmap='inferno')
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    cb = fig.colorbar(hb)
    cb.set_label('Density')
    plt.show()

# Generate random data
x_data = np.random.randn(1000)
y_data = np.random.randn(1000)

# Generate hexbin plot
generate_hexbin_plot(x_data, y_data, 'X Label', 'Y Label', 'Hexbin Plot')

# Generate scatter plot
generate_scatter_plot(x_data, y_data, 'X Label', 'Y Label', 'Scatter Plot')

# %% [markdown]
# # Training and Testin data

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

a = numpy.random.normal(3, 1, 100)
b = numpy.random.normal(150, 40, 100) / a

train_a = a[:80]
train_b = b[:80]

test_a = a[80:]
test_b = b[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_a, train_b, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_a, train_b)
plt.plot(myline, mymodel(myline),"yellow")
plt.show()

from sklearn.metrics import r2_score
r21 = r2_score(train_b, mymodel(train_a))
r22 = r2_score(test_b, mymodel(test_a))
print(r21)
print(r22)
# Out:
# 0.7988645544629799
# 0.8086921460343645

# %% [markdown]
# # Decision Tree

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/Colab Notebooks/machine_learning/diabetes.csv'
fob=open(path,)
headings=next(fob)
for rec in fob:
  diabetes=rec.split(',')
  print(diabetes)
# Out:
# ['6', '148', '72', '35', '0', '33.6', '0.627', '50', '1\n']
# ['1', '85', '66', '29', '0', '26.6', '0.351', '31', '0\n']
# ['8', '183', '64', '0', '0', '23.3', '0.672', '32', '1\n']
# ['1', '89', '66', '23', '94', '28.1', '0.167', '21', '0\n']
# ['0', '137', '40', '35', '168', '43.1', '2.288', '33', '1\n']
# ['5', '116', '74', '0', '0', '25.6', '0.201', '30', '0\n']
# ['3', '78', '50', '32', '88', '31', '0.248', '26', '1\n']
# ['10', '115', '0', '0', '0', '35.3', '0.134', '29', '0\n']
# ['2', '197', '70', '45', '543', '30.5', '0.158', '53', '1\n']
# ['8', '125', '96', '0', '0', '0', '0.232', '54', '1\n']
# ['4', '110', '92', '0', '0', '37.6', '0.191', '30', '0\n']
# ['10', '168', '74', '0', '0', '38', '0.537', '34', '1\n']
# ['10', '139', '80', '0', '0', '27.1', '1.441', '57', '0\n']
# ['1', '189', '60', '23', '846', '30.1', '0.398', '59', '1\n']
# ['5', '166', '72', '19', '175', '25.8', '0.587', '51', '1\n']
# ['7', '100', '0', '0', '0', '30', '0.484', '32', '1\n']
# ...

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/machine_learning/diabetes.csv", header=None, names=col_names)
pima.head()
# Out:
#       pregnant  glucose             bp           skin  insulin   bmi  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                    pedigree  age    label
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_26.groupby('pregnant').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_26.groupby('pregnant').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variables

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
print(X_test)
# Out:
#     pregnant insulin   bmi age glucose  bp pedigree
# 285        2       0    27  52     108  80    0.259
# 101        1       0    39  33     163  72    1.222
# 582        6       0    25  27     109  60    0.206
# 352        4       0  31.2  30     137  84    0.252
# 402        6       0  24.2  55     137  61    0.151
# ..       ...     ...   ...  ..     ...  ..      ...
# 241        1       0  29.2  21      91  64    0.192
# 429        0     145  40.6  26     135  94    0.284
# 651        1     100  25.2  23      91  54    0.234
# 11         4       0  37.6  30     110  92    0.191
# 214        0     130  42.6  24     140  65    0.431
#
# [231 rows x 7 columns]
